# %%
# Import the random module.
import random
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | rosetta
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | daru
# Processing Record 7 of Set 1 | mutsu
# Processing Record 8 of Set 1 | kysyl-syr
# Processing Record 9 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 1 | broken hill
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bulembu
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | varhaug
# Processing Record 19 of Set 1 | balgazyn
# Processing Record 20 of Set 1 | kushmurun
# Processing Record 21 of Set 1 | rudsar
# Processing Record 22 of Set 1 | lokoja
# Processing Record 23 of Set 1 | ossora
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | kabanjahe
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | lianzhou
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | karamken
# City not found. Skipping...
# Processing Record 33 of Set 1 | ukiah
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | inhambane
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | port blair
# Processing Record 38 of Set 1 | waipawa
# Processing Record 39 of Set 1 | erenhot
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | mata
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | wanning
# Processing Record 46 of Set 1 | durban
# Processing Record 47 of Set 1 | paragominas
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | yelizovo
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | prieska
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | ochiltree
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | chernyshevskiy
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | naze
# Processing Record 10 of Set 2 | boende
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | mount gambier
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | gold coast
# Processing Record 15 of Set 2 | yumen
# Processing Record 16 of Set 2 | les cayes
# Processing Record 17 of Set 2 | salto
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | kyra
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | paamiut
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | hami
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | kununurra
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | pundaguitan
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | sabaoani
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | constitucion
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | tocopilla
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | meiktila
# Processing Record 46 of Set 2 | vlakhokerasea
# City not found. Skipping...
# Processing Record 47 of Set 2 | bogande
# Processing Record 48 of Set 2 | anadyr
# Processing Record 49 of Set 2 | tarakan
# Processing Record 50 of Set 2 | aiken
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | san jose de gracia
# Processing Record 3 of Set 3 | khani
# Processing Record 4 of Set 3 | marawi
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | nioki
# Processing Record 10 of Set 3 | manturovo
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | peravurani
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | tezu
# Processing Record 17 of Set 3 | pokhara
# Processing Record 18 of Set 3 | peace river
# Processing Record 19 of Set 3 | ellensburg
# Processing Record 20 of Set 3 | haapiti
# Processing Record 21 of Set 3 | betanzos
# Processing Record 22 of Set 3 | kostomuksha
# Processing Record 23 of Set 3 | el uvito
# Processing Record 24 of Set 3 | spring hill
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | elko
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | pudozh
# Processing Record 31 of Set 3 | sasni
# Processing Record 32 of Set 3 | caravelas
# Processing Record 33 of Set 3 | consuegra
# Processing Record 34 of Set 3 | reconquista
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | yanggu
# Processing Record 37 of Set 3 | kozulka
# Processing Record 38 of Set 3 | coquimbo
# Processing Record 39 of Set 3 | ilo
# Processing Record 40 of Set 3 | fairbanks
# Processing Record 41 of Set 3 | kloulklubed
# Processing Record 42 of Set 3 | rio grande
# Processing Record 43 of Set 3 | mount isa
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | leshukonskoye
# Processing Record 46 of Set 3 | contamana
# Processing Record 47 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | kjollefjord
# Processing Record 1 of Set 4 | bulgan
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 4 | khor
# Processing Record 6 of Set 4 | batagay
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | qaqortoq
# Processing Record 9 of Set 4 | diamantino
# Processing Record 10 of Set 4 | ferkessedougou
# Processing Record 11 of Set 4 | laguna
# Processing Record 12 of Set 4 | bonthe
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | port alfred
# Processing Record 15 of Set 4 | gourcy
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | nishihara
# Processing Record 19 of Set 4 | port augusta
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | te anau
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | ajdabiya
# Processing Record 24 of Set 4 | lodi
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | sao filipe
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | guiratinga
# Processing Record 29 of Set 4 | scarborough
# Processing Record 30 of Set 4 | bridlington
# Processing Record 31 of Set 4 | farkhor
# Processing Record 32 of Set 4 | duluth
# Processing Record 33 of Set 4 | port stanley
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | kapaa
# Processing Record 36 of Set 4 | inirida
# Processing Record 37 of Set 4 | puerto ayora
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | mwanza
# Processing Record 40 of Set 4 | bubaque
# Processing Record 41 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | ambon
# Processing Record 43 of Set 4 | eydhafushi
# Processing Record 44 of Set 4 | nikolskoye
# Processing Record 45 of Set 4 | skjervoy
# Processing Record 46 of Set 4 | songjianghe
# Processing Record 47 of Set 4 | mehamn
# Processing Record 48 of Set 4 | ostrovnoy
# Processing Record 49 of Set 4 | luanda
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | hobyo
# Processing Record 3 of Set 5 | makurdi
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | pendleton
# Processing Record 6 of Set 5 | luena
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | basco
# Processing Record 10 of Set 5 | erzin
# Processing Record 11 of Set 5 | nanakuli
# Processing Record 12 of Set 5 | bukachacha
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | ust-nera
# Processing Record 15 of Set 5 | pangkalanbuun
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | norman wells
# Processing Record 18 of Set 5 | bontang
# Processing Record 19 of Set 5 | samana
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | verkhoyansk
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | lompoc
# Processing Record 24 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 25 of Set 5 | bolgatanga
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | durango
# Processing Record 28 of Set 5 | san policarpo
# Processing Record 29 of Set 5 | san bartolome
# Processing Record 30 of Set 5 | sorland
# Processing Record 31 of Set 5 | baherden
# Processing Record 32 of Set 5 | melchor de mencos
# Processing Record 33 of Set 5 | aykhal
# Processing Record 34 of Set 5 | gat
# Processing Record 35 of Set 5 | den helder
# Processing Record 36 of Set 5 | straumen
# Processing Record 37 of Set 5 | russell
# Processing Record 38 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 39 of Set 5 | imbituba
# Processing Record 40 of Set 5 | romita
# Processing Record 41 of Set 5 | westport
# Processing Record 42 of Set 5 | beroroha
# Processing Record 43 of Set 5 | ye
# City not found. Skipping...
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | puqi
# Processing Record 46 of Set 5 | beira
# Processing Record 47 of Set 5 | grants
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | hilo
# Processing Record 50 of Set 5 | shingu
# Processing Record 1 of Set 6 | longview
# Processing Record 2 of Set 6 | tessalit
# Processing Record 3 of Set 6 | broome
# Processing Record 4 of Set 6 | kaka
# Processing Record 5 of Set 6 | burley
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 6 | alampur
# Processing Record 10 of Set 6 | acapulco
# Processing Record 11 of Set 6 | honningsvag
# Processing Record 12 of Set 6 | zaozerne
# Processing Record 13 of Set 6 | wagar
# Processing Record 14 of Set 6 | lasa
# Processing Record 15 of Set 6 | saint anthony
# Processing Record 16 of Set 6 | cootamundra
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | port pirie
# Processing Record 19 of Set 6 | gobo
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | athabasca
# Processing Record 22 of Set 6 | zhuhai
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | evensk
# Processing Record 25 of Set 6 | lunca corbului
# Processing Record 26 of Set 6 | canon city
# Processing Record 27 of Set 6 | ullapool
# Processing Record 28 of Set 6 | kashi
# Processing Record 29 of Set 6 | makakilo city
# Processing Record 30 of Set 6 | san nicolas
# Processing Record 31 of Set 6 | bani
# Processing Record 32 of Set 6 | huron
# Processing Record 33 of Set 6 | nyrob
# Processing Record 34 of Set 6 | maniitsoq
# Processing Record 35 of Set 6 | kodiak
# Processing Record 36 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 6 | malaya vishera
# Processing Record 38 of Set 6 | olafsvik
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | belgaum
# Processing Record 42 of Set 6 | ginda
# Processing Record 43 of Set 6 | sawtell
# Processing Record 44 of Set 6 | hofn
# Processing Record 45 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 6 | dunedin
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | zyryanka
# Processing Record 49 of Set 6 | talnakh
# Processing Record 50 of Set 6 | salekhard
# Processing Record 1 of Set 7 | severomuysk
# Processing Record 2 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 3 of Set 7 | arlit
# Processing Record 4 of Set 7 | berbera
# Processing Record 5 of Set 7 | agadez
# Processing Record 6 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 7 | murgab
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | maumere
# Processing Record 10 of Set 7 | vardo
# Processing Record 11 of Set 7 | west norriton
# Processing Record 12 of Set 7 | marfino
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | kalmunai
# Processing Record 16 of Set 7 | raudeberg
# Processing Record 17 of Set 7 | borovoy
# Processing Record 18 of Set 7 | itarema
# Processing Record 19 of Set 7 | visby
# Processing Record 20 of Set 7 | folldal
# Processing Record 21 of Set 7 | iquique
# Processing Record 22 of Set 7 | yabrud
# Processing Record 23 of Set 7 | staryy nadym
# Processing Record 24 of Set 7 | sabha
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | senneterre
# Processing Record 27 of Set 7 | tiksi
# Processing Record 28 of Set 7 | charters towers
# Processing Record 29 of Set 7 | stokmarknes
# Processing Record 30 of Set 7 | tunduma
# Processing Record 31 of Set 7 | kanakapura
# Processing Record 32 of Set 7 | rongcheng
# Processing Record 33 of Set 7 | mareeba
# Processing Record 34 of Set 7 | sayyan
# Processing Record 35 of Set 7 | lata
# Processing Record 36 of Set 7 | ca mau
# Processing Record 37 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 7 | yaqui
# Processing Record 39 of Set 7 | oktyabrskoye
# Processing Record 40 of Set 7 | rawson
# Processing Record 41 of Set 7 | sicuani
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | vana-vigala
# Processing Record 44 of Set 7 | qasigiannguit
# Processing Record 45 of Set 7 | manggar
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | huaraz
# Processing Record 48 of Set 7 | pizarro
# Processing Record 49 of Set 7 | banda aceh
# Processing Record 50 of Set 7 | kindu
# Processing Record 1 of Set 8 | port hawkesbury
# Processing Record 2 of Set 8 | male
# Processing Record 3 of Set 8 | margate
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | sao francisco
# Processing Record 6 of Set 8 | manado
# Processing Record 7 of Set 8 | le port
# Processing Record 8 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 8 | klyuchi
# Processing Record 10 of Set 8 | goderich
# Processing Record 11 of Set 8 | price
# Processing Record 12 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 8 | basoko
# Processing Record 14 of Set 8 | bay roberts
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | zhongshu
# Processing Record 17 of Set 8 | north bend
# Processing Record 18 of Set 8 | hirara
# Processing Record 19 of Set 8 | vung tau
# Processing Record 20 of Set 8 | dingle
# Processing Record 21 of Set 8 | a
# City not found. Skipping...
# Processing Record 22 of Set 8 | fort nelson
# Processing Record 23 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 8 | umm lajj
# Processing Record 25 of Set 8 | dawlatabad
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | hudiksvall
# Processing Record 30 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 31 of Set 8 | richards bay
# Processing Record 32 of Set 8 | hailar
# Processing Record 33 of Set 8 | pathein
# Processing Record 34 of Set 8 | praia
# Processing Record 35 of Set 8 | nkoteng
# Processing Record 36 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 37 of Set 8 | isla mujeres
# Processing Record 38 of Set 8 | virginia beach
# Processing Record 39 of Set 8 | bathsheba
# Processing Record 40 of Set 8 | avera
# Processing Record 41 of Set 8 | teluknaga
# Processing Record 42 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | byron bay
# Processing Record 45 of Set 8 | nereju
# Processing Record 46 of Set 8 | nizhnyaya tura
# Processing Record 47 of Set 8 | cabo san lucas
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | kruisfontein
# Processing Record 50 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 9 | pontianak
# Processing Record 2 of Set 9 | timbiqui
# Processing Record 3 of Set 9 | olden
# Processing Record 4 of Set 9 | port lincoln
# Processing Record 5 of Set 9 | mayo
# Processing Record 6 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 9 | esperance
# Processing Record 9 of Set 9 | montego bay
# Processing Record 10 of Set 9 | pacifica
# Processing Record 11 of Set 9 | nome
# Processing Record 12 of Set 9 | hwange
# Processing Record 13 of Set 9 | teknaf
# Processing Record 14 of Set 9 | presidente medici
# Processing Record 15 of Set 9 | izumo
# Processing Record 16 of Set 9 | gaozhou
# Processing Record 17 of Set 9 | ola
# Processing Record 18 of Set 9 | manokwari
# Processing Record 19 of Set 9 | maragogi
# Processing Record 20 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | kutum
# Processing Record 22 of Set 9 | hov
# Processing Record 23 of Set 9 | tromso
# Processing Record 24 of Set 9 | birjand
# Processing Record 25 of Set 9 | itaituba
# Processing Record 26 of Set 9 | comodoro rivadavia
# Processing Record 27 of Set 9 | krasnyy bogatyr
# Processing Record 28 of Set 9 | panaba
# Processing Record 29 of Set 9 | sarakhs
# Processing Record 30 of Set 9 | svetlogorsk
# Processing Record 31 of Set 9 | ulaanbaatar
# Processing Record 32 of Set 9 | japura
# Processing Record 33 of Set 9 | vostok
# Processing Record 34 of Set 9 | churapcha
# Processing Record 35 of Set 9 | vilhena
# Processing Record 36 of Set 9 | markova
# Processing Record 37 of Set 9 | camacupa
# Processing Record 38 of Set 9 | haines junction
# Processing Record 39 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 9 | isiro
# Processing Record 41 of Set 9 | dicabisagan
# Processing Record 42 of Set 9 | khandyga
# Processing Record 43 of Set 9 | puerto colombia
# Processing Record 44 of Set 9 | mende
# Processing Record 45 of Set 9 | vila velha
# Processing Record 46 of Set 9 | englehart
# Processing Record 47 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 9 | pocone
# Processing Record 49 of Set 9 | harrisburg
# Processing Record 50 of Set 9 | narsaq
# Processing Record 1 of Set 10 | riyadh
# Processing Record 2 of Set 10 | serenje
# Processing Record 3 of Set 10 | nadym
# Processing Record 4 of Set 10 | alexandria
# Processing Record 5 of Set 10 | camocim
# Processing Record 6 of Set 10 | ixtapa
# Processing Record 7 of Set 10 | sur
# Processing Record 8 of Set 10 | funtua
# Processing Record 9 of Set 10 | yaan
# Processing Record 10 of Set 10 | turukhansk
# Processing Record 11 of Set 10 | escanaba
# Processing Record 12 of Set 10 | kayseri
# Processing Record 13 of Set 10 | bereznik
# Processing Record 14 of Set 10 | jalu
# Processing Record 15 of Set 10 | blyth
# Processing Record 16 of Set 10 | klaksvik
# Processing Record 17 of Set 10 | faya
# Processing Record 18 of Set 10 | dong hoi
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | pahrump
# Processing Record 21 of Set 10 | henties bay
# Processing Record 22 of Set 10 | cidreira
# Processing Record 23 of Set 10 | noyabrsk
# Processing Record 24 of Set 10 | alice springs
# Processing Record 25 of Set 10 | mirabad
# Processing Record 26 of Set 10 | lukulu
# Processing Record 27 of Set 10 | sunrise manor
# Processing Record 28 of Set 10 | dover
# Processing Record 29 of Set 10 | gigmoto
# Processing Record 30 of Set 10 | camacha
# Processing Record 31 of Set 10 | husavik
# Processing Record 32 of Set 10 | esna
# Processing Record 33 of Set 10 | nhulunbuy
# Processing Record 34 of Set 10 | sao felix do xingu
# Processing Record 35 of Set 10 | atar
# Processing Record 36 of Set 10 | nouadhibou
# Processing Record 37 of Set 10 | kholm
# Processing Record 38 of Set 10 | sarkand
# Processing Record 39 of Set 10 | phra phutthabat
# Processing Record 40 of Set 10 | port hardy
# Processing Record 41 of Set 10 | sulecin
# Processing Record 42 of Set 10 | panjab
# Processing Record 43 of Set 10 | kinablangan
# Processing Record 44 of Set 10 | wattegama
# Processing Record 45 of Set 10 | ratnagiri
# Processing Record 46 of Set 10 | marystown
# Processing Record 47 of Set 10 | kahului
# Processing Record 48 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 49 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 10 | celestun
# Processing Record 1 of Set 11 | taltal
# Processing Record 2 of Set 11 | nioro
# Processing Record 3 of Set 11 | mandera
# Processing Record 4 of Set 11 | nizwa
# Processing Record 5 of Set 11 | marrakesh
# Processing Record 6 of Set 11 | gatton
# Processing Record 7 of Set 11 | port-gentil
# Processing Record 8 of Set 11 | adra
# Processing Record 9 of Set 11 | sioux lookout
# Processing Record 10 of Set 11 | motihari
# Processing Record 11 of Set 11 | angoche
# Processing Record 12 of Set 11 | lincolnton
# Processing Record 13 of Set 11 | concepcion del oro
# Processing Record 14 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 15 of Set 11 | lorengau
# Processing Record 16 of Set 11 | lazaro cardenas
# Processing Record 17 of Set 11 | abu samrah
# Processing Record 18 of Set 11 | batsfjord
# Processing Record 19 of Set 11 | panguna
# Processing Record 20 of Set 11 | quelimane
# Processing Record 21 of Set 11 | chapada dos guimaraes
# Processing Record 22 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 11 | mao
# Processing Record 24 of Set 11 | neyshabur
# Processing Record 25 of Set 11 | key west
# Processing Record 26 of Set 11 | hamilton
# Processing Record 27 of Set 11 | sedro-woolley
# Processing Record 28 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 11 | katobu
# Processing Record 31 of Set 11 | challans
# Processing Record 32 of Set 11 | kuusamo
# Processing Record 33 of Set 11 | chuncheng
# Processing Record 34 of Set 11 | algiers
# Processing Record 35 of Set 11 | oromocto
# Processing Record 36 of Set 11 | flinders
# Processing Record 37 of Set 11 | khvatovka
# Processing Record 38 of Set 11 | belyy yar
# Processing Record 39 of Set 11 | la orilla
# Processing Record 40 of Set 11 | ugoofaaru
# Processing Record 41 of Set 11 | batemans bay
# Processing Record 42 of Set 11 | coruripe
# Processing Record 43 of Set 11 | coahuayana
# Processing Record 44 of Set 11 | acari
# Processing Record 45 of Set 11 | leh
# Processing Record 46 of Set 11 | hue
# Processing Record 47 of Set 11 | nanortalik
# Processing Record 48 of Set 11 | sambava
# Processing Record 49 of Set 11 | kommunar
# Processing Record 50 of Set 11 | tiarei
# Processing Record 1 of Set 12 | tautira
# Processing Record 2 of Set 12 | santiago del estero
# Processing Record 3 of Set 12 | komatipoort
# Processing Record 4 of Set 12 | pirapo
# Processing Record 5 of Set 12 | siuna
# Processing Record 6 of Set 12 | tazovskiy
# Processing Record 7 of Set 12 | dudinka
# Processing Record 8 of Set 12 | katherine
# Processing Record 9 of Set 12 | mamallapuram
# Processing Record 10 of Set 12 | bulolo
# Processing Record 11 of Set 12 | lixourion
# Processing Record 12 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 14 of Set 12 | nogliki
# Processing Record 15 of Set 12 | axim
# Processing Record 16 of Set 12 | port elizabeth
# Processing Record 17 of Set 12 | douglas
# Processing Record 18 of Set 12 | saint-raymond
# Processing Record 19 of Set 12 | coolum beach
# Processing Record 20 of Set 12 | padilla
# Processing Record 21 of Set 12 | saint-pierre
# Processing Record 22 of Set 12 | menongue
# Processing Record 23 of Set 12 | malangali
# Processing Record 24 of Set 12 | mitsamiouli
# Processing Record 25 of Set 12 | vanavara
# Processing Record 26 of Set 12 | ndele
# Processing Record 27 of Set 12 | lukovetskiy
# Processing Record 28 of Set 12 | kyshtovka
# Processing Record 29 of Set 12 | antofagasta
# Processing Record 30 of Set 12 | tilichiki
# Processing Record 31 of Set 12 | kasungu
# Processing Record 32 of Set 12 | nouakchott
# Processing Record 33 of Set 12 | puerto ayacucho
# Processing Record 34 of Set 12 | finschhafen
# Processing Record 35 of Set 12 | kigorobya
# Processing Record 36 of Set 12 | ciudad bolivar
# Processing Record 37 of Set 12 | gharb
# City not found. Skipping...
# Processing Record 38 of Set 12 | mildura
# Processing Record 39 of Set 12 | ponnani
# Processing Record 40 of Set 12 | vredendal
# Processing Record 41 of Set 12 | casselman
# Processing Record 42 of Set 12 | leirvik
# Processing Record 43 of Set 12 | hovd
# Processing Record 44 of Set 12 | strezhevoy
# Processing Record 45 of Set 12 | nenjiang
# Processing Record 46 of Set 12 | flagstaff
# Processing Record 47 of Set 12 | bien hoa
# Processing Record 48 of Set 12 | nemuro
# Processing Record 49 of Set 12 | noumea
# Processing Record 50 of Set 12 | porosozero
# Processing Record 1 of Set 13 | baza
# Processing Record 2 of Set 13 | sitka
# Processing Record 3 of Set 13 | genhe
# Processing Record 4 of Set 13 | bilibino
# Processing Record 5 of Set 13 | gamba
# Processing Record 6 of Set 13 | santa maria
# Processing Record 7 of Set 13 | sakakah
# Processing Record 8 of Set 13 | necochea
# Processing Record 9 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 13 | egvekinot
# Processing Record 12 of Set 13 | voyinka
# Processing Record 13 of Set 13 | teya
# Processing Record 14 of Set 13 | santa catalina
# Processing Record 15 of Set 13 | tigil
# Processing Record 16 of Set 13 | huilong
# Processing Record 17 of Set 13 | san-pedro
# Processing Record 18 of Set 13 | palaikastron
# Processing Record 19 of Set 13 | tafresh
# Processing Record 20 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 13 | tura
# Processing Record 22 of Set 13 | marigot
# Processing Record 23 of Set 13 | lindsay
# Processing Record 24 of Set 13 | khandbari
# Processing Record 25 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 13 | sandwick
# Processing Record 27 of Set 13 | buala
# Processing Record 28 of Set 13 | shelburne
# Processing Record 29 of Set 13 | biak
# Processing Record 30 of Set 13 | rio verde de mato grosso
# Processing Record 31 of Set 13 | kavieng
# Processing Record 32 of Set 13 | port macquarie
# Processing Record 33 of Set 13 | jilmah
# City not found. Skipping...
# Processing Record 34 of Set 13 | bonham
# Processing Record 35 of Set 13 | astara
# Processing Record 36 of Set 13 | sinop
# Processing Record 37 of Set 13 | taonan
# Processing Record 38 of Set 13 | omboue
# Processing Record 39 of Set 13 | aden
# Processing Record 40 of Set 13 | belmonte
# Processing Record 41 of Set 13 | melong
# Processing Record 42 of Set 13 | badah
# Processing Record 43 of Set 13 | palauig
# Processing Record 44 of Set 13 | tabou
# Processing Record 45 of Set 13 | brahmapuri
# City not found. Skipping...
# Processing Record 46 of Set 13 | iguape
# Processing Record 47 of Set 13 | terrace bay
# Processing Record 48 of Set 13 | salalah
# Processing Record 49 of Set 13 | kirksville
# Processing Record 50 of Set 13 | yeppoon
# Processing Record 1 of Set 14 | eyl
# Processing Record 2 of Set 14 | novyy urengoy
# Processing Record 3 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 14 | fare
# Processing Record 5 of Set 14 | beloha
# Processing Record 6 of Set 14 | kieta
# Processing Record 7 of Set 14 | solnechnyy
# Processing Record 8 of Set 14 | pishva
# Processing Record 9 of Set 14 | mandiana
# Processing Record 10 of Set 14 | ishigaki
# Processing Record 11 of Set 14 | bikaner
# Processing Record 12 of Set 14 | gualeguay
# Processing Record 13 of Set 14 | phatthalung
# Processing Record 14 of Set 14 | kamiichi
# Processing Record 15 of Set 14 | qena
# Processing Record 16 of Set 14 | emerald
# Processing Record 17 of Set 14 | salinopolis
# Processing Record 18 of Set 14 | bastia
# Processing Record 19 of Set 14 | slave lake
# Processing Record 20 of Set 14 | jaru
# Processing Record 21 of Set 14 | herat
# Processing Record 22 of Set 14 | srednekolymsk
# Processing Record 23 of Set 14 | sistranda
# Processing Record 24 of Set 14 | diosjeno
# Processing Record 25 of Set 14 | nara
# Processing Record 26 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 14 | gladstone
# Processing Record 28 of Set 14 | doha
# Processing Record 29 of Set 14 | beeskow
# Processing Record 30 of Set 14 | gasa
# Processing Record 31 of Set 14 | aqtobe
# Processing Record 32 of Set 14 | jumla
# Processing Record 33 of Set 14 | neiafu
# Processing Record 34 of Set 14 | novoagansk
# Processing Record 35 of Set 14 | caconda
# Processing Record 36 of Set 14 | kanchanaburi
# Processing Record 37 of Set 14 | manaus
# Processing Record 38 of Set 14 | polyarnyy
# Processing Record 39 of Set 14 | klin
# Processing Record 40 of Set 14 | saint-francois
# Processing Record 41 of Set 14 | sangmelima
# Processing Record 42 of Set 14 | muriti
# Processing Record 43 of Set 14 | ostersund
# Processing Record 44 of Set 14 | guerrero negro
# Processing Record 45 of Set 14 | golpayegan
# Processing Record 46 of Set 14 | terre haute
# Processing Record 47 of Set 14 | talaya
# Processing Record 48 of Set 14 | sovetskiy
# Processing Record 49 of Set 14 | invermere
# Processing Record 50 of Set 14 | vanimo
# Processing Record 1 of Set 15 | carmen
# Processing Record 2 of Set 15 | stadthagen
# Processing Record 3 of Set 15 | pangody
# Processing Record 4 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 15 | gull lake
# Processing Record 6 of Set 15 | santa cruz
# Processing Record 7 of Set 15 | mujiayingzi
# Processing Record 8 of Set 15 | torbay
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | rio gallegos
# Processing Record 11 of Set 15 | smolenka
# Processing Record 12 of Set 15 | talara
# Processing Record 13 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 14 of Set 15 | skelleftea
# Processing Record 15 of Set 15 | san vicente
# Processing Record 16 of Set 15 | sechura
# Processing Record 17 of Set 15 | labuhan
# Processing Record 18 of Set 15 | boueni
# Processing Record 19 of Set 15 | yar-sale
# Processing Record 20 of Set 15 | fairview
# Processing Record 21 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 15 | kamennogorsk
# Processing Record 23 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 15 | hualmay
# Processing Record 25 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 26 of Set 15 | lima
# Processing Record 27 of Set 15 | poum
# Processing Record 28 of Set 15 | yuncheng
# Processing Record 29 of Set 15 | lunca cernii de jos
# Processing Record 30 of Set 15 | anloga
# Processing Record 31 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 15 | namwala
# Processing Record 33 of Set 15 | kingisepp
# Processing Record 34 of Set 15 | tokur
# Processing Record 35 of Set 15 | siniscola
# Processing Record 36 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 15 | bandarbeyla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0             busselton      AU -33.6500  115.3333     58.05        57
# 1               rosetta      EG  31.4044   30.4164     78.62        64
# 2                 vaini      TO -21.2000 -175.2000     80.76        83
# 3              tasiilaq      GL  65.6145  -37.6368     26.26        62
# 4               ushuaia      AR -54.8000  -68.3000     35.26        69
# 5                  daru      PG  -9.0763  143.2092     78.82        72
# 6                 mutsu      JP  41.2894  141.2169     71.92        60
# 7             kysyl-syr      RU  63.8986  122.7617     47.77        55
# 8              souillac      MU -20.5167   57.5167     70.36        94
# 9  vila franca do campo      PT  37.7167  -25.4333     68.41        89
#
#    Cloudiness  Wind Speed Current Description
# 0          70       12.46       broken clouds
# 1           1       15.52           clear sky
# 2          20        8.05          few clouds
# 3          24        6.67          few clouds
# 4          75        5.75          light snow
# 5          97       19.71     overcast clouds
# 6         100        8.23     overcast clouds
# 7         100       11.03     overcast clouds
# 8          75        3.44       broken clouds
# 9          92        4.18     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
